# %% [markdown]
# ## **EDA performed on Cleaned Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96516 entries, 0 to 96515
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           96516 non-null  object
#  1   items_in_order     96516 non-null  int64
#  2   customer_id        96516 non-null  object
#  3   customer_state     96516 non-null  object
#  4   product_id         96516 non-null  object
#  5   product_density    96516 non-null  float64
#  6   price              96516 non-null  float64
#  7   category           96516 non-null  object
#  8   seller_id          96516 non-null  object
#  9   seller_state       96516 non-null  object
#  10  rating             96516 non-null  int64
#  11  delivery_time      96516 non-null  int64
#  12  delivery_charge    96516 non-null  float64
#  13  payment_type       96516 non-null  object
#  14  total_payment      96516 non-null  float64
#  15  total_installment  96516 non-null  int64
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
#customer state
df['customer_state'].nunique()
# Out:
# 13

# %%
#plot
df['customer_state'].value_counts().plot(kind='bar')
plt.xlabel('States')
plt.ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
# category
df['category'].value_counts()
# Out:
# category
# home                   25447
# Electronics            15463
# Toys                   15071
# Health                 14711
# Fashion                 7939
# Construction            5339
# Automotive              3861
# stationery              2279
# Pet                     1696
# luggage_accessories     1019
# Art                      991
# Food_Drink               955
# Book_Media               921
# Industry                 824
# Name: count, dtype: int64

# %%
#plot
df['category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
# seller state
df['seller_state'].nunique()
# Out:
# 7

# %%
#plot
df['seller_state'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='seller_state'>

# %%
# payment type
print(df['payment_type'].value_counts())
df['payment_type'].value_counts().plot(kind='bar')
# Out:
# payment_type
# credit_card    72156
# voucher        20704
# multiple        2172
# debit_card      1484
# Name: count, dtype: int64
# <Axes: xlabel='payment_type'>

# %%
# order status
print(df['order_status'].value_counts())
df["order_status"].value_counts().plot(kind='bar')
# Out:
# order_status
# delivered     94488
# processing     1594
# canceled        434
# Name: count, dtype: int64
# <Axes: xlabel='order_status'>

# %%
# review score
df['rating'].value_counts()
df['rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
# 1  Analysis between price and delivery_charge
sns.scatterplot(data=df, x='price', y='delivery_charge')
plt.title('Price vs Delivery Charge')
plt.show()


# 2  Analysis between category and rating
sns.boxplot(data=df, x='category', y='rating')
plt.xticks(rotation=90)
plt.title('Product Category vs Rating')
plt.show()


# 3  Analysis between payment_type and rating
sns.boxplot(data=df, x='payment_type', y='rating')
plt.title('Payment Type vs Rating')
plt.show()


# 4  Analysis between customer_state and delivery_charge
sns.barplot(data=df, x='customer_state', y='delivery_charge', estimator='mean')
plt.xticks(rotation=90)
plt.title('Average Delivery Charge by Customer State')
plt.show()


# 5  Analysis between items_in_order and total_payment
sns.scatterplot(data=df, x='items_in_order', y='total_payment')
plt.title('Items in Order vs Total Payment')
plt.show()

# %%
# 6  Analysis between price and rating
sns.scatterplot(data=df, x='rating', y='price')
plt.title('Product Price vs Rating')
plt.show()


# 7  Analysis between category and total_payment
sns.barplot(data=df, x='category', y='total_payment', estimator='mean')
plt.xticks(rotation=90)
plt.title('Average Total Payment by Product Category')
plt.show()


# 8  Analysis between seller_state and delivery_charge
sns.barplot(data=df, x='seller_state', y='delivery_charge', estimator='mean')
plt.xticks(rotation=90)
plt.title('Average Delivery Charge by Seller State')
plt.show()


# 9  Analysis between payment_type and total_payment
sns.scatterplot(data=df, x='payment_type', y='total_payment')
plt.title('Payment Type vs Total Payment')
plt.show()


# 10  Analysis between rating and delivery_charge
sns.scatterplot(data=df, x='rating', y='delivery_charge')
plt.title('Delivery Charge vs Rating')
plt.show()

# %%
# 11  Analysis between customer_state and total_payment
sns.barplot(data=df, x='customer_state', y='total_payment', estimator='mean')
plt.xticks(rotation=90)
plt.title('Average Total Payment by Customer State')
plt.show()


# 12  Analysis between product_density and delivery_charge
sns.scatterplot(data=df, x='product_density', y='delivery_charge')
plt.title('Product Density vs Delivery Charge')
plt.show()


# 13  Analysis between category and delivery_charge
sns.barplot(data=df, x='category', y='delivery_charge', estimator='mean')
plt.xticks(rotation=90)
plt.title('Average Delivery Charge by Product Category')
plt.show()


# 14  Analysis between payment_type and price
sns.scatterplot(data=df, x='payment_type', y='price')
plt.title('Payment Type vs Product Price')
plt.show()


# 15  Analysis between seller_state and rating
sns.boxplot(data=df, x='seller_state', y='rating')
plt.xticks(rotation=90)
plt.title('Seller State vs Rating')
plt.show()

# %%
# 16  Analysis between order_status and rating
sns.boxplot(data=df, x='order_status', y='rating')
plt.title('Order Status vs Rating')
plt.show()


# 17  Analysis between price and total_payment
sns.scatterplot(data=df, x='price', y='total_payment')
plt.title('Product Price vs Total Payment')
plt.show()


# 18  Analysis between delivery_charge and total_payment
sns.scatterplot(data=df, x='delivery_charge', y='total_payment')
plt.title('Delivery Charge vs Total Payment')
plt.show()


# 19  Analysis between category and order_status
sns.countplot(data=df, x='category', hue='order_status')
plt.xticks(rotation=90)
plt.title('Order Status Distribution by Product Category')
plt.show()


# 20  Analysis between product_density and price
sns.scatterplot(data=df, x='product_density', y='price')
plt.title('Product Density vs Product Price')
plt.show()

# %%
# 21  Analysis between delivery_time and rating
sns.boxplot(data=df, x='rating', y='delivery_time')
plt.title('Delivery Time vs Rating')
plt.show()


# 22  Analysis between delivery_time and delivery_charge
sns.scatterplot(data=df, x='delivery_time', y='delivery_charge')
plt.title('Delivery Time vs Delivery Charge')
plt.show()


# 23  Analysis between total_installment and total_payment
sns.scatterplot(data=df, x='total_payment', y='total_installment')
plt.title('Total Payment vs Installments')
plt.show()

# %%
# 24  Analysis between items_in_order and delivery_time
sns.scatterplot(data=df, x='items_in_order', y='delivery_time')
plt.title('Items in Order vs Delivery Time')
plt.show()


# 25  Analysis between seller_state and delivery_time
sns.barplot(data=df, x='seller_state', y='delivery_time', estimator='mean')
plt.xticks(rotation=90)
plt.title('Average Delivery Time by Seller State')
plt.show()
